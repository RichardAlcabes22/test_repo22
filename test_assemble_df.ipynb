# %%
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_json('data_r1.json', orient='records')

# %%
df
# Out:
#                                                 repo language  \
# 0                            ujjwalkarn/DataScienceR        R
# 1                         IndrajeetPatil/ggstatsplot        R
# 2                                easystats/easystats        R
# 3                                 seandavi/sars2pack        R
# 4                           markvanderloo/lumberjack        R
# 5                       benubah/r-community-explorer        R
# 6                       cattystats/Anomaly_Detection        R
# 7  anishsingh20/Human-Resource-Analytics-and-Empl...        R
# 8            adityashrm21/Bike-Sharing-Demand-Kaggle        R
# 9                                  arbuzovv/rusquant        R
#
#                                      readme_contents
# 0  # R Data Science Tutorials\n- This repo contai...
# 1  ---\noutput: github_document\n---\n\n  <!-- RE...
# 2  ---\noutput: github_document\n---\n\n```{r, wa...
# 3  ---\noutput: \n  - rmarkdown::github_document\...
# ...

# %%
pd.concat([df,pd.read_json('data_r2.json', orient='records')],ignore_index=True)
# Out:
#                                                  repo language  \
# 0                             ujjwalkarn/DataScienceR        R
# 1                          IndrajeetPatil/ggstatsplot        R
# 2                                 easystats/easystats        R
# 3                                  seandavi/sars2pack        R
# 4                            markvanderloo/lumberjack        R
# 5                        benubah/r-community-explorer        R
# 6                        cattystats/Anomaly_Detection        R
# 7   anishsingh20/Human-Resource-Analytics-and-Empl...        R
# 8             adityashrm21/Bike-Sharing-Demand-Kaggle        R
# 9                                   arbuzovv/rusquant        R
# 10          anishsingh20/Statistical-Learning-using-R        R
# 11                 Netflix/user2020-metaflow-tutorial        R
# 12         parulnith/A-guide-to-Machine-Learning-in-R        R
# 13  Rpita623/Movie-Recommendation-System-using-R_P...        R
# ...

# %%
json = [pd.read_json('data_r1.json', orient='records'),
        pd.read_json('data_r2.json', orient='records'),
        pd.read_json('data_r3.json', orient='records'),
        pd.read_json('data_r4.json', orient='records'),
        pd.read_json('data_r5.json', orient='records'),
        pd.read_json('data_r6.json', orient='records'),
        pd.read_json('data_r7_8.json', orient='records'),
        pd.read_json('data_r9_10_11_12.json', orient='records'),
        pd.read_json('data_r13_14.json', orient='records'),
        pd.read_json('data_r15_16.json', orient='records'),
        pd.read_json('data_r17_18.json', orient='records')]

# %%
pd.concat([pd.read_json('data_r1.json', orient='records'),
        pd.read_json('data_r2.json', orient='records'),
          pd.read_json('data_r3.json', orient='records')],ignore_index=True)
# Out:
#                                                  repo language  \
# 0                             ujjwalkarn/DataScienceR        R
# 1                          IndrajeetPatil/ggstatsplot        R
# 2                                 easystats/easystats        R
# 3                                  seandavi/sars2pack        R
# 4                            markvanderloo/lumberjack        R
# 5                        benubah/r-community-explorer        R
# 6                        cattystats/Anomaly_Detection        R
# 7   anishsingh20/Human-Resource-Analytics-and-Empl...        R
# 8             adityashrm21/Bike-Sharing-Demand-Kaggle        R
# 9                                   arbuzovv/rusquant        R
# 10          anishsingh20/Statistical-Learning-using-R        R
# 11                 Netflix/user2020-metaflow-tutorial        R
# 12         parulnith/A-guide-to-Machine-Learning-in-R        R
# 13  Rpita623/Movie-Recommendation-System-using-R_P...        R
# ...

# %%
pd.concat(json,ignore_index=True)
# Out:
#                                   repo language  \
# 0              ujjwalkarn/DataScienceR        R
# 1           IndrajeetPatil/ggstatsplot        R
# 2                  easystats/easystats        R
# 3                   seandavi/sars2pack        R
# 4             markvanderloo/lumberjack        R
# ..                                 ...      ...
# 170                         leenock/ML        R
# 171    Phelipe-Sempreboni/data-science        R
# 172  fernandapilat/r-para-data-science        R
# 173     lcasilva/Projeto_DSA_Feedback2        R
# 174     lcasilva/Projeto_DSA_feedback1        R
#
#                                        readme_contents
# 0    # R Data Science Tutorials\n- This repo contai...
# 1    ---\noutput: github_document\n---\n\n  <!-- RE...
# 2    ---\noutput: github_document\n---\n\n```{r, wa...
# 3    ---\noutput: \n  - rmarkdown::github_document\...
# 4    ## Track changes in data\n[![Build Status](htt...
# ...

# %%
df = pd.concat(json,ignore_index=True)

# %%
df.to_csv('langr_raw.csv')

# %%
jsonp = [pd.read_json('data_p1_2.json', orient='records'),
        pd.read_json('data_p3_4.json', orient='records'),
        pd.read_json('data_p5_6.json', orient='records'),
        pd.read_json('data_p7_8.json', orient='records'),
        pd.read_json('data_p9_10.json', orient='records'),
        pd.read_json('data_p11_12.json', orient='records'),
        pd.read_json('data_p13_14.json', orient='records'),
        pd.read_json('data_p15_16.json', orient='records'),
        pd.read_json('data_p17_18.json', orient='records')]

# %%
dfp = pd.concat(jsonp,ignore_index=True)

# %%
dfp
# Out:
#                                               repo language  \
# 0                                 ludwig-ai/ludwig   Python
# 1                              modin-project/modin   Python
# 2                                 Netflix/metaflow   Python
# 3                              lk-geimfari/mimesis   Python
# 4                                    holoviz/panel   Python
# ..                                             ...      ...
# 175                 rahulbordoloi/Machine-Learning   Python
# 176                           Oslandia/QDeeplandia   Python
# 177  arjunbhasin2013/BaselinePredictionMLFramework   Python
# 178              PonderaLab/datascience4economists   Python
# 179                           joaoariedi/etl_luigi   Python
#
#                                        readme_contents
# 0    ![Ludwig logo](https://github.com/ludwig-ai/lu...
# 1    <p align="center"><a href="https://modin.readt...
# 2    ![Metaflow_Logo_Horizontal_FullColor_Ribbon_Da...
# ...

# %%
dfp.to_csv('langp_raw.csv')
